# %%
import pandas as pd #Data Manipulation
import numpy as np #Mathematical Opearation
import matplotlib.pyplot as plt #Data Visualization
from sklearn.linear_model import LinearRegression #Data Modeling

# %%
df = pd.read_csv('/content/Lesson_4_student_grades_dataset.csv', encoding='latin-1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-017ef392a374> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/Lesson_4_student_grades_dataset.csv', encoding='latin-1')
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Lesson_4_student_grades_dataset.csv'

# %%
hours_of_study = 10

X = np.random.randint(0, 10, hours_of_study)
Y = 2 * X + np.random.normal(0,10, hours_of_study)

# %%
data = pd.DataFrame({'HOURS': X, 'GRADE': Y})

data.to_csv('/content/Lesson_4_student_grades_dataset.csv', index = False)

print(data.head())
# Out:
#    HOURS      GRADE
# 0      4   1.482411
# 1      4  31.742527
# 2      3   2.830298
# 3      5  20.432465
# 4      1  10.666939

# %%
plt.scatter(data['X'], data['Y'])
plt.xlabel('Hours of Study')
plt.ylabel('Dependent Variable (Y)')
plt.title('Scatter Plots of Data')
# Out:
# Text(0.5, 1.0, 'Scatter Plots of Data')

# %%
X = data[['X']] #Independent Variable
Y = data[['Y']] #Dependent Variable

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0]

intercept = model.intercept_

print('Slope',slope)
print('Intercept', intercept)
# Out:
# Slope [-1.52944771]
# Intercept [25.4718544]

# %%
plt.scatter(X,Y)
plt.plot(X,model.predict(X), color = 'indigo')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f8e66b480213> in <cell line: 1>()
# ----> 1 plt.scatter(X,Y)
#       2 plt.plot(X,model.predict(X), color = 'indigo')
#       3 plt.xlabel('Independent Variable (X)')
#       4 plt.ylabel('Dependent Variable (Y)')
#       5 plt.title('')
#
# NameError: name 'plt' is not defined
